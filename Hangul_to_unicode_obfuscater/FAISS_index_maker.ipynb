# %% [markdown]
# # FAISS 인덱스 제작
# 이 노트북은 단계별로 이미지를 생성/불러와 OCR 모델로 벡터를 추출하고 FAISS 인덱스를 만드는 예시입니다.
# 각 코드 셀을 순서대로 실행하세요.

# %%
# %pip install numpy pillow tensorflow faiss-cpu
# Out:
# Requirement already satisfied: numpy in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: pillow in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (11.3.0)
# Requirement already satisfied: tensorflow in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (2.20.0)
# Requirement already satisfied: faiss-cpu in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (1.13.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\stayup24h\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 라이브러리 임포트 및 스크립트 불러오기
import os
import numpy as np
import tensorflow as tf
import faiss
import gc

# %%
# inline helper 함수들 정의
import math
from PIL import Image, ImageDraw, ImageFont

# faiss는 나중에 설치되어야 합니다. 노트북 상단에서 설치 커맨드를 실행하세요.
try:
    import faiss
except Exception:
    faiss = None

import numpy as np
import tensorflow as tf

# 한글 음절 분해/평가용 슬라이스 (모델 출력 인덱스에 맞춤)
L_SLICE = slice(0, 19)
V_SLICE = slice(19, 40)
T_SLICE = slice(40, 68)

# 손실/지표 함수 (모델 로드에 필요할 수 있음)
def hangul_loss(y_true, logits):
    cho  = tf.nn.softmax_cross_entropy_with_logits(labels=y_true[:, L_SLICE], logits=logits[:, L_SLICE])
    jung = tf.nn.softmax_cross_entropy_with_logits(labels=y_true[:, V_SLICE], logits=logits[:, V_SLICE])
    jong = tf.nn.softmax_cross_entropy_with_logits(labels=y_true[:, T_SLICE], logits=logits[:, T_SLICE])
    return cho + jung + jong


def acc_first(y_true, y_pred):
    return tf.reduce_mean(tf.cast(tf.equal(tf.argmax(y_true[:, L_SLICE], -1), tf.argmax(y_pred[:, L_SLICE], -1)), tf.float32))

def acc_middle(y_true, y_pred):
    return tf.reduce_mean(tf.cast(tf.equal(tf.argmax(y_true[:, V_SLICE], -1), tf.argmax(y_pred[:, V_SLICE], -1)), tf.float32))

def acc_last(y_true, y_pred):
    return tf.reduce_mean(tf.cast(tf.equal(tf.argmax(y_true[:, T_SLICE], -1), tf.argmax(y_pred[:, T_SLICE], -1)), tf.float32))

def acc_joint(y_true, y_pred):
    l_ok = tf.equal(tf.argmax(y_true[:, L_SLICE], -1), tf.argmax(y_pred[:, L_SLICE], -1))
    v_ok = tf.equal(tf.argmax(y_true[:, V_SLICE], -1), tf.argmax(y_pred[:, V_SLICE], -1))
    t_ok = tf.equal(tf.argmax(y_true[:, T_SLICE], -1), tf.argmax(y_pred[:, T_SLICE], -1))
    return tf.reduce_mean(tf.cast(l_ok & v_ok & t_ok, tf.float32))


# 글자 렌더링 함수 (노트북 환경에서 바로 사용)
def render_char_to_tensor(char: str, image_size=(128,128), font_path: str = None, font_size: int = 96):
    W, H = image_size
    try:
        if font_path and os.path.exists(font_path):
            font = ImageFont.truetype(font_path, font_size)
        else:
            font = ImageFont.load_default()
    except Exception:
        font = ImageFont.load_default()

    image = Image.new("L", (W, H), "white")
    draw = ImageDraw.Draw(image)

    try:
        bbox = draw.textbbox((0, 0), char, font=font)
        text_width = bbox[2] - bbox[0]
        text_height = bbox[3] - bbox[1]
        position = ((W - text_width) / 2 - bbox[0], (H - text_height) / 2 - bbox[1])
    except Exception:
        position = (5,5)

    draw.text(position, char, font=font, fill="black")
    arr = np.array(image, dtype=np.float32) / 255.0
    return arr.reshape((H, W, 1))


# 텐서 로드 또는 코드포인트 범위로부터 생성
def load_or_generate_tensors(tensors_path, labels_path):
    if tensors_path and os.path.exists(tensors_path):
        print(f"Loading tensors from {tensors_path}")
        X = np.load(tensors_path)
        if labels_path and os.path.exists(labels_path):
            labels = np.load(labels_path, allow_pickle=True)
        else:
            raise ValueError("Labels file required when providing tensors. Use --labels <file>.")
        return X, labels


# 모델로부터 벡터를 추출하는 함수 (배치 처리)
def extract_vectors(model, X: np.ndarray, batch_size: int = 256, encoder=None):
    N = X.shape[0]
    parts = []
    for i in range(0, N, batch_size):
        batch = X[i:i+batch_size].astype(np.float32)
        preds = model.predict(batch, verbose=0)
        if encoder is not None:
            preds = encoder.predict(preds, verbose=0)
        parts.append(preds.astype(np.float32))
    vectors = np.concatenate(parts, axis=0)
    return vectors


# FAISS 인덱스 빌드 함수
def ensure_faiss():
    if faiss is None:
        raise RuntimeError("faiss not available. Install with 'pip install faiss-cpu'.")


def build_index(vectors: np.ndarray, mapping: np.ndarray, out_index_path: str, nprobe: int = 20):
    ensure_faiss()
    n, d = vectors.shape
    print(f"Building FAISS index for {n} vectors, dim={d}")
    if n > 5000:
        nlist = int(max(64, math.sqrt(n)))
        quantizer = faiss.IndexFlatL2(d)
        index = faiss.IndexIVFFlat(quantizer, d, nlist, faiss.METRIC_L2)
        print(f"Training IVF index with nlist={nlist}...")
        index.train(vectors)
        index.add(vectors)
    else:
        index = faiss.IndexFlatL2(d)
        index.add(vectors)
    try:
        index.nprobe = nprobe
    except Exception:
        pass
    faiss.write_index(index, out_index_path)
    print(f"Saved FAISS index to {out_index_path}")

# %% [markdown]
# ## 1) 설정
# - `DRIVE_BASE`: Google Drive 내 프로젝트 루트 경로
# - `UNICODE_TENSOR_DIR`: 인쇄체 유니코드 텐서(`unicode_tensors_*.npy`)와 라벨(`unicode_labels_*.npy`) 폴더
# - `COMBINED_UNICODE_TENSOR_DIR`: 조합 유니코드 텐서(`combined_unicode_tensors_*.npy`)와 라벨(`combined_unicode_labels_*.npy`) 폴더
# - `MODEL_PATH`: OCR 모델 (`final.keras`) 경로
# - `LABELS_PATH`: 한글 음절 레이블 파일 경로

# %%
DRIVE_BASE = "/content/drive/MyDrive/기계학습기초"

# 인쇄체 유니코드 텐서/라벨 폴더
UNICODE_TENSOR_DIR = f"{DRIVE_BASE}/datasets/unicode_images_150"
UNICODE_LABEL_DIR = UNICODE_TENSOR_DIR
UNICODE_FILE_COUNT = 16

# 조합 유니코드 텐서/라벨 폴더
COMBINED_UNICODE_TENSOR_DIR = f"{DRIVE_BASE}/datasets/combined_unicode_images_150"
COMBINED_UNICODE_LABEL_DIR = COMBINED_UNICODE_TENSOR_DIR
COMBINED_UNICODE_FILE_COUNT = 13

# OCR 모델 경로
MODEL_PATH = f"{DRIVE_BASE}/final.keras"

# 라벨 파일 경로 (한글 음절)
LABELS_PATH = f"{DRIVE_BASE}/hangul_labels.npy"

# %% [markdown]
# ## 2) OCR 모델 로드
# - 학습한 `final.keras` 모델 파일 경로를 지정하세요.

# %%
#OCR 모델 로드 (MODEL_PATH는 설정 셀에서 정의됨)

L_SLICE = slice(0, 19)
V_SLICE = slice(19, 40)
T_SLICE = slice(40, 68)

def hangul_loss(y_true, logits):
    cho  = tf.nn.softmax_cross_entropy_with_logits(labels=y_true[:, L_SLICE], logits=logits[:, L_SLICE])
    jung = tf.nn.softmax_cross_entropy_with_logits(labels=y_true[:, V_SLICE], logits=logits[:, V_SLICE])
    jong = tf.nn.softmax_cross_entropy_with_logits(labels=y_true[:, T_SLICE], logits=logits[:, T_SLICE])
    return cho + jung + jong

def acc_first(y_true, y_pred):
    return tf.reduce_mean(tf.cast(tf.equal(tf.argmax(y_true[:, L_SLICE], -1),
                                           tf.argmax(y_pred[:, L_SLICE], -1)), tf.float32))
def acc_middle(y_true, y_pred):
    return tf.reduce_mean(tf.cast(tf.equal(tf.argmax(y_true[:, V_SLICE], -1),
                                           tf.argmax(y_pred[:, V_SLICE], -1)), tf.float32))
def acc_last(y_true, y_pred):
    return tf.reduce_mean(tf.cast(tf.equal(tf.argmax(y_true[:, T_SLICE], -1),
                                           tf.argmax(y_pred[:, T_SLICE], -1)), tf.float32))
def acc_joint(y_true, y_pred):
    l_ok = tf.equal(tf.argmax(y_true[:, L_SLICE], -1), tf.argmax(y_pred[:, L_SLICE], -1))
    v_ok = tf.equal(tf.argmax(y_true[:, V_SLICE], -1), tf.argmax(y_pred[:, V_SLICE], -1))
    t_ok = tf.equal(tf.argmax(y_true[:, T_SLICE], -1), tf.argmax(y_pred[:, T_SLICE], -1))
    return tf.reduce_mean(tf.cast(l_ok & v_ok & t_ok, tf.float32))

import keras

# Keras 3 버전 호환성 패치: 모든 레이어에서 quantization_config 인자를 무시하도록 설정
original_layer_init = keras.layers.Layer.__init__
def patched_layer_init(self, *args, **kwargs):
    kwargs.pop('quantization_config', None)
    original_layer_init(self, *args, **kwargs)
keras.layers.Layer.__init__ = patched_layer_init

model = keras.models.load_model(
    MODEL_PATH,
    custom_objects={
        "hangul_loss": hangul_loss,
        "acc_first": acc_first,
        "acc_middle": acc_middle,
        "acc_last": acc_last,
        "acc_joint": acc_joint,
    }
)
print("모델 로드 완료:", MODEL_PATH)
# Out:
# c:\Users\stayup24h\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 320 variables whereas the saved optimizer has 324 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# ## 3) 벡터 추출
# - `unicode_images_150` / `combined_unicode_images_150` 폴더에 저장된 인쇄체 유니코드 텐서를 불러옵니다.
# - `unicode_tensors_*.npy` / `combined_unicode_tensors_*.npy` 파일에서 이미지 텐서 로드
# - 대응하는 라벨 파일 `unicode_labels_*.npy` / `combined_unicode_labels_*.npy` 도 함께 로드
# - OCR 모델로 예측하여 68차원 벡터 추출, 메모리 절약을 위해 파일 단위로 처리

# %%
BATCH_SIZE = 256
encoder_model_path = None
encoder = None

if encoder_model_path:
    encoder = keras.models.load_model(encoder_model_path)

TENSOR_FILE_PATHS = []
LABEL_FILE_PATHS = []

for i in range(UNICODE_FILE_COUNT):
    TENSOR_FILE_PATHS.append(f"{UNICODE_TENSOR_DIR}/unicode_tensors_{i}.npy")
    LABEL_FILE_PATHS.append(f"{UNICODE_LABEL_DIR}/unicode_labels_{i}.npy")

for i in range(COMBINED_UNICODE_FILE_COUNT):
    TENSOR_FILE_PATHS.append(
        f"{COMBINED_UNICODE_TENSOR_DIR}/combined_unicode_tensors_{i}.npy"
    )
    LABEL_FILE_PATHS.append(
        f"{COMBINED_UNICODE_LABEL_DIR}/combined_unicode_labels_{i}.npy"
    )

print(f"처리할 파일 수: {len(TENSOR_FILE_PATHS)}")

vectors_list = []
labels_list = []

for tensor_path, label_path in zip(TENSOR_FILE_PATHS, LABEL_FILE_PATHS):
    if not os.path.exists(tensor_path):
        print(f"[SKIP] 파일 없음: {tensor_path}")
        continue

    print(f"Loading: {tensor_path}")
    X = np.load(tensor_path, mmap_mode='r')
    sample_count = len(X)

    if os.path.exists(label_path):
        lbl = np.load(label_path, allow_pickle=True)
        labels_list.extend(lbl.tolist())
    else:
        print(f"  [WARNING] 라벨 파일 없음: {label_path}")
        labels_list.extend([f"unk_{os.path.basename(tensor_path)}_{j}" for j in range(sample_count)])

    for start in range(0, sample_count, BATCH_SIZE):
        batch = np.asarray(X[start:start + BATCH_SIZE], dtype=np.float32)

        if batch.ndim == 3:
            batch = np.expand_dims(batch, axis=-1)

        if np.issubdtype(X.dtype, np.integer):
            batch /= 255.0
        elif batch.size > 0 and np.max(batch) > 1.5:
            batch /= 255.0

        preds = model.predict(batch, verbose=0)
        if encoder is not None:
            preds = encoder.predict(preds, verbose=0)
        vectors_list.append(preds.astype(np.float32))

        del batch, preds

    print(f"  -> {sample_count} 이미지 처리 완료")

    del X
    gc.collect()

vectors = np.concatenate(vectors_list, axis=0)
labels = labels_list

print(f"\n벡터 형상: {vectors.shape}")
print(f"라벨 수: {len(labels)}")

np.save('unicode_vectors.npy', vectors)
np.save('all_unicode_labels.npy', np.array(labels, dtype=object))
print('저장 완료: unicode_vectors.npy, all_unicode_labels.npy')
# Out:
# Total Unicode characters to process: 55512
# Rendering characters and extracting vectors (Batch Size: 32)...
#   Processed 3200 / 55512 characters
#   Processed 6400 / 55512 characters
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 58
#      55     batch = batch / 255.0
#      57 # 모델 예측
# ---> 58 preds = model.predict(batch, verbose=0)
#      59 vectors_list.append(preds)
#      61 # 배치 초기화
#
# File c:\Users\stayup24h\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\stayup24h\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:566, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     564 callbacks.on_predict_batch_begin(begin_step)
#     565 data = get_data(iterator)
# --> 566 batch_outputs = self.predict_function(data)
#     567 outputs = append_to_outputs(batch_outputs, outputs)
#     568 callbacks.on_predict_batch_end(
#     569     end_step, {"outputs": batch_outputs}
#     570 )
#
# File c:\Users\stayup24h\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\stayup24h\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\stayup24h\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\stayup24h\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\stayup24h\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\stayup24h\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\stayup24h\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\stayup24h\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\stayup24h\AppData\Local\Programs\Python\Python313\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 4) FAISS 인덱스 생성 및 저장
# - 데이터 수에 따라 Flat 또는 IVF 인덱스를 자동으로 선택합니다.
# - `nprobe`는 검색시 탐색할 클러스터 개수로, 정확도/속도 조정을 위해 변경 가능합니다.

# %%
# FAISS 인덱스 빌드
OUT_INDEX = 'hangle_faiss_index.faiss'
OUT_MAP = 'faiss_hangle_map.npy'
NPROBE = 20

encoder_model_path = None
encoder = None

if encoder_model_path:
    import keras
    encoder = keras.models.load_model(encoder_model_path)

IMAGE_HEIGHT = 150
IMAGE_WIDTH = 150
FONT_SIZE = 112

FAISS_INDEX_FILENAME = 'hangle_faiss_index.faiss'

# --- FAISS 인덱스 설정 ---
NLIST = 100  # 클러스터(Partition) 개수. (데이터 개수의 sqrt 근처 값 권장)

final_unicode_X = np.load('unicode_vectors.npy')
final_unicode_X = np.array(final_unicode_X)


D = final_unicode_X

# 1. Quantizer 정의: 벡터를 클러스터링할 때 사용할 기준 (일반적으로 L2 거리를 사용하는 Flat 인덱스 사용)
# 'D' 대신 벡터의 차원 (D.shape[1])을 전달해야 합니다.
quantizer = faiss.IndexFlatL2(D.shape[1])

# 2. IVF 인덱스 생성: D차원, NLIST개의 클러스터, L2 거리 사용
# 'D' 대신 벡터의 차원 (D.shape[1])을 전달해야 합니다.
index = faiss.IndexIVFFlat(quantizer, D.shape[1], NLIST, faiss.METRIC_L2)

# 3. 인덱스 훈련 (Training)
# IVF 인덱스는 add 전에 클러스터 중심점을 계산하는 훈련이 필요합니다.
print("FAISS Index Training Start...")
index.train(final_unicode_X)
print("Training Complete. Index is trained:", index.is_trained)

# 4. 벡터 추가 (Adding)
# 16차원 잠재 벡터를 인덱스에 추가합니다.
index.add(final_unicode_X)
print(f"Total vectors added: {index.ntotal}")

# 5. 검색 속도 vs. 정확도 설정 (nprobe)
# 검색 시 확인할 클러스터의 개수. 높을수록 정확하나 느립니다.
# 20만 개에서는 10~30 사이가 적절하며, 20을 추천합니다.
index.nprobe = 20

# 6. 인덱스 저장
faiss.write_index(index, FAISS_INDEX_FILENAME)
print(f"FAISS Index saved as {FAISS_INDEX_FILENAME}")
# Out:
# FAISS Index Training Start...
# Training Complete. Index is trained: True
# Total vectors added: 11172
# FAISS Index saved as hangle_faiss_index.faiss

# %% [markdown]
# ## 5) 간단 검색 예시
# - 생성한 FAISS 인덱스와 매핑을 불러와 샘플 문자로 검색해봅니다.

# %%
import faiss

index = faiss.read_index(OUT_INDEX)
u_map = np.load('all_unicode_labels.npy', allow_pickle=True)

query_char = '켭'
q_tensor = render_char_to_tensor(
    query_char,
    image_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    font_path=None,
    font_size=FONT_SIZE,
 )
q_tensor = np.expand_dims(q_tensor, 0).astype(np.float32)
q_vec = model.predict(q_tensor)

if encoder is not None:
    q_vec = encoder.predict(q_vec)

print(q_vec)
D, I = index.search(q_vec, 10)
print('Top results:')
for rank, (idx, dist) in enumerate(zip(I[0], D[0])):
    if idx >= 0:
        print(f"{rank+1}. character={u_map[idx]} dist={dist}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# [[6.6411023e-11 2.4153862e-10 2.1197631e-15 1.2201361e-16 6.4177137e-15
#   6.3949925e-13 2.2971956e-12 7.7160110e-13 1.7159600e-10 2.5266284e-18
#   1.7508796e-17 7.7347295e-12 5.9759678e-15 2.8305991e-16 6.2186042e-14
#   7.2617394e-01 5.4069582e-15 2.3334757e-14 9.2594522e-11 1.2251377e-13
#   9.0953466e-16 9.1146372e-13 8.2201475e-11 7.2746062e-08 2.9658245e-13
#   4.9755678e-02 3.6342428e-08 5.7241305e-13 6.9574049e-17 1.5611582e-20
#   1.5340906e-12 1.4311247e-12 3.5002901e-14 1.2320620e-10 2.1378308e-16
#   1.2418720e-10 1.9627588e-14 3.2906654e-14 1.5237707e-15 1.1589814e-10
#   1.4502512e-10 4.6007317e-13 2.0196589e-18 8.2440782e-18 3.3100228e-10
#   1.9194283e-14 6.2876815e-11 7.8745240e-15 1.2978935e-10 2.6124481e-17
#   2.1803507e-18 9.7551437e-13 1.2355646e-16 7.0511043e-18 6.9978368e-17
#   1.5017093e-16 1.1007676e-08 2.2407025e-01 1.5537165e-09 1.1151693e-12
#   3.3260200e-11 3.7428841e-11 3.7204367e-18 2.8350330e-14 3.4129824e-11
#   1.5567178e-10 1.0084097e-12 6.9642962e-13]]
# Top results:
# 1. character=켭 dist=7.566275144199608e-07
# 2. character=컙 dist=0.011912645772099495
# 3. character=쿱 dist=0.048117198050022125
# 4. character=쾁 dist=0.05151689052581787
# 5. character=켝 dist=0.06779901683330536
# 6. character=켣 dist=0.0701388344168663
# 7. character=큡 dist=0.07154795527458191
# 8. character=켠 dist=0.07652390003204346
# 9. character=켨 dist=0.07747248560190201
# 10. character=콕 dist=0.0780138373374939
